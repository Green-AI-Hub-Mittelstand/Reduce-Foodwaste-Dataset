# %%
import numpy as np
import pandas as pd

# %%
training_data = pd.read_csv("train.csv")

# %%
training_data.head()
# Out:
#          date    store is_state_holiday is_school_holiday is_special_day  \
# 0  2021-08-02  store_5       normal_day    school_holiday     normal_day
# 1  2021-08-02  store_8       normal_day    school_holiday     normal_day
# 2  2021-08-02  store_7       normal_day    school_holiday     normal_day
# 3  2021-08-02  store_4       normal_day    school_holiday     normal_day
# 4  2021-08-02  store_1       normal_day    school_holiday     normal_day
#
#    temperature_max  temperature_min  temperature_mean  sunshine_sum  \
# 0             21.8             16.3         19.590909           203
# 1             21.8             16.3         19.590909           203
# 2             21.8             16.3         19.590909           203
# 3             21.8             16.3         19.590909           203
# 4             21.8             16.3         19.590909           203
#
#    precipitation_sum     sales  unsold  ordered
# 0                0.0  1.432748     NaN      NaN
# ...

# %%
for group_name, group in training_data.groupby("store"):
    group.plot("date", "sales", figsize=(18,4), title=group_name + " sales")
